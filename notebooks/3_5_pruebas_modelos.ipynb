# %% [markdown]
# # Creación del modelo

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import sys
import random
import matplotlib.pyplot as plt
import numpy as np
import keras

CURRENT_DIR = Path('/content/drive')
from google.colab import drive
drive.mount(str(CURRENT_DIR))

CURRENT_DIR = CURRENT_DIR.joinpath('MyDrive','restauracion')
MODULES_DIR = CURRENT_DIR.joinpath('src')
sys.path.append(str(MODULES_DIR))
DATA_DIR = CURRENT_DIR.joinpath('Process')

# %config InlineBackend.figure_format = 'retina'
import tensorflow as tf
from keras.models import Model, load_model
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Lista de todas las GPUs disponibles en el sistema
gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
    # Si hay al menos una GPU disponible, establecer el uso de solo una GPU
    tf.config.experimental.set_visible_devices(gpus[0], 'GPU')

    # Limitar la capacidad de la GPU a 10 GB
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=12*1024)])  # 10 GB en MB

    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print("Usando solo 1 de", len(gpus), "GPU físicas y", len(logical_gpus), "GPU lógicas")
else:
    print("No se encontraron GPUs disponibles.")
# Out:
# Usando solo 1 de 1 GPU físicas y 1 GPU lógicas

# %%
x_input, y_input = 1204,1701

# %% [markdown]
# ----
# # Carga de datos

# %%
from sklearn.model_selection import train_test_split
from keras.utils import img_to_array, load_img

# %%
directories_clean = sorted([f for f in DATA_DIR.joinpath('test').iterdir() if f.is_dir()])
files_clean = []
for folder in directories_clean:
    files_clean = sorted(DATA_DIR.joinpath('test',folder.name).glob('*.jpg')) + files_clean

files_clean = sorted(files_clean)

# %%
directories_noisy = sorted([f for f in DATA_DIR.joinpath('train').iterdir() if f.is_dir()])
files_noisy = []
for folder in directories_clean:
    files_noisy = sorted(DATA_DIR.joinpath('train',folder.name).glob('*.jpg')) + files_noisy

files_noisy = sorted(files_noisy)

# %%
x_train_list, x_test_list, y_train_list, y_test_list = train_test_split(
    files_noisy,
    files_clean,
    test_size=0.2
)

# %%
import data_load

# %%
trainning_generator = data_load.CustomImageDataGenerator(
    image_paths_noisy=x_train_list,
    image_paths_clean=y_train_list,
    batch_size=6,
    target_size=(x_input, y_input),
    class_mode='input',
    shuffle=True)

# %%
testing_generator = data_load.CustomImageDataGenerator(
    image_paths_noisy=x_test_list,
    image_paths_clean=y_test_list,
    batch_size=6,
    target_size=(x_input, y_input),
    class_mode='input',
    shuffle=True)

# %% [markdown]
# -----
#
# # Creación del modelo

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization
from keras.optimizers import Adam
from keras.models import Model, Sequential

# %%
input = Input(
    shape=(x_input,y_input, 1),
    name= 'Image_Input')

# %% [markdown]
# ## Decoder

# %%
x = Conv2D(
    filters = 16,
    kernel_size = (3,3),
    activation = 'relu',
    padding = 'same',
    name = 'Convolutional_Layer_1')(input)

x = Conv2D(
    filters = 16,
    kernel_size = (3,3),
    activation = 'relu',
    padding = 'same',
    name = 'Convolutional_Layer_2')(x)

x = Conv2D(
    filters = 16,
    kernel_size = (3,3),
    activation = 'relu',
    padding = 'same',
    name = 'Convolutional_Layer_3')(x)

x = Conv2D(
    filters = 20,
    kernel_size = (3,3),
    activation = 'relu',
    padding = 'same',
    name = 'Convolutional_Layer_3_1')(x)

x = BatchNormalization()(x)

# %% [markdown]
# ## Encoder

# %%
x = Conv2D(
    filters = 20,
    kernel_size = (3,3),
    activation = 'relu',
    padding = 'same',
    name = 'Convolutional_Layer_5')(x)

x = Conv2D(
    filters = 16,
    kernel_size = (3,3),
    activation = 'relu',
    padding = 'same',
    name = 'Convolutional_Layer_6')(x)

x = Conv2D(
    filters = 8,
    kernel_size = (3,3),
    activation = 'relu',
    padding = 'same',
    name = 'Convolutional_Layer_7')(x)


x = Conv2D(
    filters = 4,
    kernel_size = (3,3),
    activation = 'relu',
    padding = 'same',
    name = 'Convolutional_Layer_8')(x)

x = BatchNormalization()(x)

decoded = Conv2D(
    filters = 1,
    kernel_size= (3, 3),
    activation='sigmoid',
    padding='same',
    name = 'decoder')(x)

# %%
autoencoder = Model(input,decoded)
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Image_Input (InputLayer)    [(None, 1204, 1701, 1)]   0
#
#  Convolutional_Layer_1 (Conv  (None, 1204, 1701, 16)   160
#  2D)
#
#  Convolutional_Layer_2 (Conv  (None, 1204, 1701, 16)   2320
#  2D)
#
#  Convolutional_Layer_3 (Conv  (None, 1204, 1701, 16)   2320
#  2D)
#
#  Convolutional_Layer_3_1 (Co  (None, 1204, 1701, 20)   2900
#  nv2D)
#
#  batch_normalization (BatchN  (None, 1204, 1701, 20)   80
#  ormalization)
#
#  Convolutional_Layer_5 (Conv  (None, 1204, 1701, 20)   3620
#  2D)
#
#  Convolutional_Layer_6 (Conv  (None, 1204, 1701, 16)   2896
#  2D)
#
#  Convolutional_Layer_7 (Conv  (None, 1204, 1701, 8)    1160
#  2D)
#
#  Convolutional_Layer_8 (Conv  (None, 1204, 1701, 4)    292
#  2D)
#
#  batch_normalization_1 (Batc  (None, 1204, 1701, 4)    16
#  hNormalization)
#
#  decoder (Conv2D)            (None, 1204, 1701, 1)     37
#
# =================================================================
# Total params: 15,801
# Trainable params: 15,753
# Non-trainable params: 48
# _________________________________________________________________

# %%
autoencoder.compile(optimizer='adam', loss='mae', metrics=['mse',tf.keras.metrics.LogCoshError()])

# %%
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# %%
keras.utils.plot_model(autoencoder, "autoencoder_v_2_0.png", show_shapes=True)

# %% [markdown]
# ------
#
# # Carga del modelo anterior

# %% [markdown]
# modelo_previamente_entrenado = load_model(str(DATA_DIR.joinpath('modelo_v_0_3.h5')))
# capas_seleccionadas = ['Convolutional_Layer_1','Convolutional_Layer_2','Convolutional_Layer_3']
# aaa1 = ['Convolutional_Layer_3']
# pesos_seleccionados = [modelo_previamente_entrenado.get_layer(nombre_capa).get_weights() for nombre_capa in capas_seleccionadas]
# pesos_seleccionados2 = [modelo_previamente_entrenado.get_layer(nombre_capa).get_weights() for nombre_capa in aaa1]
#
#
# # Establecer los pesos en el nuevo modelo
# for capa, peso in zip(autoencoder.layers[1:], pesos_seleccionados):
#     capa.set_weights(peso)
#
# for capa, peso in zip(autoencoder.layers[5:], pesos_seleccionados2):
#     capa.set_weights(peso)

# %%
autoencoder.fit(
    trainning_generator,
    epochs=10,
    steps_per_epoch=len(trainning_generator),
    shuffle=True,
    validation_data=testing_generator,
    validation_steps=len(testing_generator)
)
# Out:
# Epoch 1/10
# 201/201 [==============================] - 338s 2s/step - loss: 0.0986 - mse: 0.0306 - logcosh: 0.0146 - val_loss: 0.0852 - val_mse: 0.0212 - val_logcosh: 0.0102
# Epoch 2/10
# 201/201 [==============================] - 287s 1s/step - loss: 0.0459 - mse: 0.0080 - logcosh: 0.0039 - val_loss: 0.0752 - val_mse: 0.0172 - val_logcosh: 0.0083
# Epoch 3/10
# 201/201 [==============================] - 286s 1s/step - loss: 0.0387 - mse: 0.0068 - logcosh: 0.0033 - val_loss: 0.0501 - val_mse: 0.0099 - val_logcosh: 0.0048
# Epoch 4/10
# 201/201 [==============================] - 286s 1s/step - loss: 0.0368 - mse: 0.0065 - logcosh: 0.0032 - val_loss: 0.0773 - val_mse: 0.0118 - val_logcosh: 0.0057
# Epoch 5/10
# 201/201 [==============================] - 285s 1s/step - loss: 0.0361 - mse: 0.0064 - logcosh: 0.0031 - val_loss: 0.0817 - val_mse: 0.0111 - val_logcosh: 0.0054
# Epoch 6/10
# 201/201 [==============================] - 287s 1s/step - loss: 0.0350 - mse: 0.0063 - logcosh: 0.0030 - val_loss: 0.0580 - val_mse: 0.0091 - val_logcosh: 0.0044
# Epoch 7/10
#  84/201 [===========>..................] - ETA: 2:27 - loss: 0.0350 - mse: 0.0061 - logcosh: 0.0029

# %%
autoencoder.save(str(DATA_DIR.joinpath('modelo_v_2_1.h5')))

# %% [markdown]
# -----
#
# Prueba de resultados

# %%
x,y = testing_generator.__getitem__(random.randint(0,9))

# %%
output1 = autoencoder.predict(y)

# %%
from tensorflow.keras.preprocessing.image import array_to_img

# %%
i = random.randint(0,5)
fig, ax = plt.subplots(3,1, figsize=(15,30))

a1 = array_to_img(np.array(x[i] * 255, dtype=np.uint8))
ax[0].imshow(a1, cmap='gray')
ax[0].set_title('Imagen con defectos')
ax[0].axis(False)

a2 = array_to_img(np.array(y[i] * 255, dtype=np.uint8))
ax[1].imshow(a2,cmap='gray')
ax[1].set_title('Imagen real limpia')
ax[1].axis(False)

a3 = array_to_img(np.array(output1[i] * 255, dtype=np.uint8))
ax[2].imshow(a1,cmap='gray')
ax[2].set_title('Procesada')
ax[2].axis(False)
plt.show()

# %% [markdown]
# ----

# %%
autoencoder.fit(
    trainning_generator,
    epochs=10,
    steps_per_epoch=len(trainning_generator),
    shuffle=True,
    validation_data=testing_generator,
    validation_steps=len(testing_generator)
)

# %%
autoencoder.save(str(DATA_DIR.joinpath('modelo_v_2_2.h5')))

# %%
x,y = testing_generator.__getitem__(random.randint(0,9))
output1 = autoencoder.predict(y)
i = random.randint(0,5)
fig, ax = plt.subplots(3,1, figsize=(15,30))

a1 = array_to_img(np.array(x[i] * 255, dtype=np.uint8))
ax[0].imshow(a1, cmap='gray')
ax[0].set_title('Imagen con defectos')
ax[0].axis(False)

a2 = array_to_img(np.array(y[i] * 255, dtype=np.uint8))
ax[1].imshow(a2,cmap='gray')
ax[1].set_title('Imagen real limpia')
ax[1].axis(False)

a3 = array_to_img(np.array(output1[i] * 255, dtype=np.uint8))
ax[2].imshow(a1,cmap='gray')
ax[2].set_title('Procesada')
ax[2].axis(False)
plt.show()

# %% [markdown]
# -----

# %%
autoencoder.fit(
    trainning_generator,
    epochs=60,
    steps_per_epoch=len(trainning_generator),
    shuffle=True,
    validation_data=testing_generator,
    validation_steps=len(testing_generator)
)

# %%
autoencoder.save(str(DATA_DIR.joinpath('modelo_v_2_3.h5')))

# %%
x,y = testing_generator.__getitem__(random.randint(0,9))
output1 = autoencoder.predict(y)
i = random.randint(0,5)
fig, ax = plt.subplots(3,1, figsize=(15,30))

a1 = array_to_img(np.array(x[i] * 255, dtype=np.uint8))
ax[0].imshow(a1, cmap='gray')
ax[0].set_title('Imagen con defectos')
ax[0].axis(False)

a2 = array_to_img(np.array(y[i] * 255, dtype=np.uint8))
ax[1].imshow(a2,cmap='gray')
ax[1].set_title('Imagen real limpia')
ax[1].axis(False)

a3 = array_to_img(np.array(output1[i] * 255, dtype=np.uint8))
ax[2].imshow(a1,cmap='gray')
ax[2].set_title('Procesada')
ax[2].axis(False)
plt.show()

# %%
autoencoder.fit(
    trainning_generator,
    epochs=60,
    steps_per_epoch=len(trainning_generator),
    shuffle=True,
    validation_data=testing_generator,
    validation_steps=len(testing_generator)
)

# %%
autoencoder.save(str(DATA_DIR.joinpath('modelo_v_2_3.h5')))

# %%
x,y = testing_generator.__getitem__(random.randint(0,9))
output1 = autoencoder.predict(y)
i = random.randint(0,5)
fig, ax = plt.subplots(3,1, figsize=(15,30))

a1 = array_to_img(np.array(x[i] * 255, dtype=np.uint8))
ax[0].imshow(a1, cmap='gray')
ax[0].set_title('Imagen con defectos')
ax[0].axis(False)

a2 = array_to_img(np.array(y[i] * 255, dtype=np.uint8))
ax[1].imshow(a2,cmap='gray')
ax[1].set_title('Imagen real limpia')
ax[1].axis(False)

a3 = array_to_img(np.array(output1[i] * 255, dtype=np.uint8))
ax[2].imshow(a1,cmap='gray')
ax[2].set_title('Procesada')
ax[2].axis(False)
plt.show()
